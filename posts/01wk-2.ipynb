# %% [raw]
# ---
# title: "01wk-1: 라인플랏, 산점도, 객체지향적 시각화"
# author: "최규빈"
# date: "09/04/2023"
# categories:
#   - matplotlib
# ---

# %% [markdown]
# <a href="https://colab.research.google.com/github/guebin/DV2023/blob/main/posts/01wk-2.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" style="text-align: left"></a>

# %% [markdown]
# # 강의영상

# %%
# {{<video  >}}

# %% [markdown]
# # imports

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib
matplotlib.rcParams['figure.figsize'] = (3, 2) 
matplotlib.rcParams['figure.dpi'] = 150

# %% [markdown]
# # Line plot

# %% [markdown]
# ## 기본플랏

# %% [markdown]
# `-` 예시1

# %%
x=[1,2,3,4]
y=[1,2,4,3]

# %%
plt.plot(x,y)

# %% [markdown]
# ## 모양변경

# %% [markdown]
# `-` 예시1

# %%
plt.plot(x,y,'--')

# %% [markdown]
# `-` 예시2

# %%
plt.plot(x,y,':')

# %% [markdown]
# `-` 예시3

# %%
plt.plot(x,y,'-.')

# %% [markdown]
# ## 색상변경

# %% [markdown]
# `-` 예시1

# %%
plt.plot(x,y,'r')

# %% [markdown]
# `-` 예시2

# %%
plt.plot(x,y,'k')

# %% [markdown]
# ## 모양 + 색상변경

# %% [markdown]
# `-` 예시1

# %%
plt.plot(x,y,'--r')

# %% [markdown]
# `-` 예시2: 순서변경 가능

# %%
plt.plot(x,y,'r--')

# %% [markdown]
# ## 원리?

# %% [markdown]
# `-` `r--`등의 옵션은 Markers + Line Styles + Colors 의 조합으로 표현가능

# %% [markdown]
# ref: <https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html>

# %% [markdown]
# - `--r`: 점선(dashed)스타일 + 빨간색
# - `r--`: 빨간색 + 점선(dashed)스타일
# - `:k`: 점선(dotted)스타일 + 검은색
# - `k:`: 검은색 + 점선(dotted)스타일

# %% [markdown]
# `-` 우선 Marker를 무시하면 Line Styles + Color로 표현가능한 조합은 $4\times 8=32$ 개

# %% [markdown]
# **(Line Styles)** 모두 4개

# %% [markdown]
# | character | description|
# |:-:|:-:|
# | '-' | solid line style |
# | '--' | dashed line style |
# | '-.' | dash-dot line style |
# | ':' | dotted line style|

# %% [markdown]
# **(Color)** 모두 8개

# %% [markdown]
# |character|color|
# |:-:|:-:|
# |'b'| blue|
# |'g'|green|
# |'r'|red|
# |'c'|cyan|
# |'m'|magenta|
# |'y'|yellow|
# |'k'|black|
# |'w'|white|

# %% [markdown]
# `-` 예시1

# %%
plt.plot(x,y,'--m')

# %% [markdown]
# `-` 예시2

# %%
plt.plot(x,y,'-.c')

# %% [markdown]
# `-` 예시3: line style + color 조합으로 사용하든 color + line style 조합으로 사용하든 상관없음

# %%
plt.plot(x,y,'-.c')

# %%
plt.plot(x,y,'c-.')

# %% [markdown]
# `-` 예시4: line style을 중복으로 사용하거나 color를 중복으로 쓸 수 는 없다.

# %%
plt.plot(x,y,'--:')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 plt.plot(x,y,'--:')
#
# File ~/anaconda3/envs/mp/lib/python3.10/site-packages/matplotlib/pyplot.py:2812, in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
#    2814         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~/anaconda3/envs/mp/lib/python3.10/site-packages/matplotlib/axes/_axes.py:1688, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1445 """
#    1446 Plot y versus x as lines and/or markers.
#    1447
#    (...)
#    1685 (``'green'``) or hex strings (``'#008000'``).
#    1686 """
#    1687 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1688 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689 for line in lines:
#    1690     self.add_line(line)
#
# File ~/anaconda3/envs/mp/lib/python3.10/site-packages/matplotlib/axes/_base.py:311, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     309     this += args[0],
#     310     args = args[1:]
# --> 311 yield from self._plot_args(
#     312     this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~/anaconda3/envs/mp/lib/python3.10/site-packages/matplotlib/axes/_base.py:454, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     451 if len(tup) > 1 and isinstance(tup[-1], str):
#     452     # xy is tup with fmt stripped (could still be (y,) only)
#     453     *xy, fmt = tup
# --> 454     linestyle, marker, color = _process_plot_format(
#     455         fmt, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#     456 elif len(tup) == 3:
#     457     raise ValueError('third arg must be a format string')
#
# File ~/anaconda3/envs/mp/lib/python3.10/site-packages/matplotlib/axes/_base.py:175, in _process_plot_format(fmt, ambiguous_fmt_datakey)
#     173 if fmt[i:i+2] in mlines.lineStyles:  # First, the two-char styles.
#     174     if linestyle is not None:
# --> 175         raise ValueError(errfmt.format(fmt, "two linestyle symbols"))
#     176     linestyle = fmt[i:i+2]
#     177     i += 2
#
# ValueError: '--:' is not a valid format string (two linestyle symbols)

# %%
plt.plot(x,y,'rb')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 plt.plot(x,y,'rb')
#
# File ~/anaconda3/envs/mp/lib/python3.10/site-packages/matplotlib/pyplot.py:2812, in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
#    2814         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~/anaconda3/envs/mp/lib/python3.10/site-packages/matplotlib/axes/_axes.py:1688, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1445 """
#    1446 Plot y versus x as lines and/or markers.
#    1447
#    (...)
#    1685 (``'green'``) or hex strings (``'#008000'``).
#    1686 """
#    1687 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1688 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689 for line in lines:
#    1690     self.add_line(line)
#
# File ~/anaconda3/envs/mp/lib/python3.10/site-packages/matplotlib/axes/_base.py:311, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     309     this += args[0],
#     310     args = args[1:]
# --> 311 yield from self._plot_args(
#     312     this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~/anaconda3/envs/mp/lib/python3.10/site-packages/matplotlib/axes/_base.py:454, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     451 if len(tup) > 1 and isinstance(tup[-1], str):
#     452     # xy is tup with fmt stripped (could still be (y,) only)
#     453     *xy, fmt = tup
# --> 454     linestyle, marker, color = _process_plot_format(
#     455         fmt, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#     456 elif len(tup) == 3:
#     457     raise ValueError('third arg must be a format string')
#
# File ~/anaconda3/envs/mp/lib/python3.10/site-packages/matplotlib/axes/_base.py:190, in _process_plot_format(fmt, ambiguous_fmt_datakey)
#     188 elif c in mcolors.get_named_colors_mapping():
#     189     if color is not None:
# --> 190         raise ValueError(errfmt.format(fmt, "two color symbols"))
#     191     color = c
#     192     i += 1
#
# ValueError: 'rb' is not a valid format string (two color symbols)

# %% [markdown]
# `-` 예시5: 색이 사실 8개만 있는건 아니다.

# %% [markdown]
# ref: <https://matplotlib.org/2.0.2/examples/color/named_colors.html>

# %%
plt.plot(x,y,'--',color='lime')

# %% [markdown]
# `-` 예시6: 색을 바꾸려면 Hex코드를 밖아 넣는 방법이 젤 깔끔함

# %% [markdown]
# ref: <https://htmlcolorcodes.com/>

# %%
plt.plot(x,y,color='#277E41')

# %% [markdown]
# `-` 예시7: 당연히 라인스타일도 4개만 있진 않음

# %% [markdown]
# ref: <https://matplotlib.org/stable/gallery/lines_bars_and_markers/linestyles.html>

# %%
plt.plot(x,y,linestyle='dashed')

# %%
plt.plot(x,y,linestyle=(0, (20, 5)))

# %% [markdown]
# # Scatter plot

# %% [markdown]
# ## 원리

# %% [markdown]
# `-` 그냥 마커를 설정하면 끝!

# %% [markdown]
# ref: <https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html>

# %% [markdown]
# |character | description|
# |:-:|:-:|
# |'.'| point marker|
# |','|pixel marker|
# |'o'|circle marker|
# |'v'| triangle_down marker |
# |'^'|triangle_up marker|
# |'<'|triangle_left marker|
# |'>'|triangle_right marker|
# |'1'|tri_down marker|
# |'2'|tri_up marker|
# |'3'|tri_left marker|
# |'4'|tri_right marker|
# |'8'|octagon marker|
# |'s'|square marker|
# |'p'|pentagon marker|
# |'P'|plus (filled) marker|
# |'*'|star marker|
# |'h'|hexagon1 marker|
# |'H'|hexagon2 marker|
# |'+'|plus marker|
# |'x'|x marker|
# |'X'|x (filled) marker|
# |'D'|diamond marker|
# |'d'|thin_diamond marker|
# |'\|'|vline marker|
# |'_'|hline marker|

# %%
plt.plot(x,y,'o')

# %% [markdown]
# ## 기본플랏

# %% [markdown]
# `-` 예시1

# %%
plt.plot(x,y,'.')

# %% [markdown]
# `-` 예시2

# %%
plt.plot(x,y,'x')

# %% [markdown]
# ## 색깔변경

# %% [markdown]
# `-` 예시1

# %%
plt.plot(x,y,'or')

# %% [markdown]
# `-` 예시2

# %%
plt.plot(x,y,'db')

# %% [markdown]
# `-` 예시3

# %%
plt.plot(x,y,'bx')

# %% [markdown]
# ## dot-connected plot

# %% [markdown]
# `-` 예시1: 마커와 라인스타일을 동시에 사용하면 dot-connected plot이 된다.

# %%
plt.plot(x,y,'o-')

# %% [markdown]
# `-` 예시2: 당연히 색도 적용가능함

# %%
plt.plot(x,y,'o--r')

# %% [markdown]
# `-` 예시3: 서로 순서를 바꿔도 상관없다.

# %%
plt.plot(x,y,'ro--')

# %% [markdown]
# # 겹쳐 그리기

# %% [markdown]
# `-` 예시1

# %%
plt.plot([1,2,3,2],'--o')
plt.plot([2,3,1,4],'--o')

# %% [markdown]
# `-` 예시2

# %%
plt.plot([1,2,3,2],'--ob')
plt.plot([2,3,1,4],'--or')

# %% [markdown]
# `-` 예시3

# %%
x = np.arange(-5,5,0.1)
eps = np.random.randn(100) 
y = 2*x + eps

# %%
plt.plot(x,y,'.b')
plt.plot(x,2*x,'--r')

# %% [markdown]
# ---

# %% [markdown]
# `-` summary: boxplot, histogram, lineplot, scatterplot
#
# - 라인플랏: 추세
# - 스캐터플랏: 두 변수의 관계
# - 박스플랏: 분포(일상용어)의 비교, 이상치
# - 히스토그램: 분포(통계용어)파악
# - 바플랏: 크기비교

# %% [markdown]
# ---

# %% [markdown]
# # 객체지향적 시각화

# %% [markdown]
# ## 예비학습

# %% [markdown]
# `# 예비학습1` -- 그림을 저장했다가 꺼내보고 싶다.

# %% [markdown]
# `-` 아래의 그림을 그리고 저장하자.

# %%
plt.plot([1, 2, 3, 2],'--o')
fig = plt.gcf() # 현재그림을 저장하는 코드

# %% [markdown]
# `-` 다른그림을 그려보자.

# %%
plt.plot([1,2,3,1])

# %% [markdown]
# `-` 저장한 그림은 언제든지 꺼내볼 수 있음

# %%
fig

# %% [markdown]
# `#`

# %% [markdown]
# `# 예비학습2` -- fig 는 뭐야?

# %%
#fig??
type(fig)
# Out:
# matplotlib.figure.Figure

# %% [markdown]
# - `Figure`라는 클래스에서 찍힌 인스턴스

# %% [markdown]
# `-` 여러가지 값, 기능이 저장되어 있겠음.

# %%
fig.axes # 뭐지?
# Out:
# [<Axes: >]

# %%
fig.axes[0] # 뭐지??
# Out:
# <Axes: >

# %%
fig.axes[0].axis() #이건 대충 알겠다
# Out:
# (-0.15000000000000002, 3.15, 0.9, 3.1)

# %%
fig

# %% [markdown]
# `-` 계층구조: Figure $\supset$ [Axes,...] $\supset$ YAxis, XAxis, [Line2D,...]

# %%
type(fig)
# Out:
# matplotlib.figure.Figure

# %%
ax = fig.axes[0]
type(ax)
# Out:
# matplotlib.axes._axes.Axes

# %%
yaxis = ax.yaxis
xaxis = ax.xaxis
type(yaxis), type(xaxis)
# Out:
# (matplotlib.axis.YAxis, matplotlib.axis.XAxis)

# %%
line2d = ax.get_lines()
type(line2d)
# Out:
# matplotlib.cbook.silent_list

# %% [markdown]
# `-` 오브젝트내용 확인 (그닥 필요 없음)

# %%
xaxis.get_data_interval()
# Out:
# array([0., 3.])

# %%
yaxis.get_data_interval()
# Out:
# array([1., 3.])

# %%
line.properties()['data']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 line.properties()['data']
#
# NameError: name 'line' is not defined

# %% [markdown]
# `-` matplotlib의 설명

# %% [markdown]
# ref: https://matplotlib.org/stable/gallery/showcase/anatomy.html#sphx-glr-gallery-showcase-anatomy-py

# %% [markdown]
# ![](https://matplotlib.org/stable/_images/sphx_glr_anatomy_001.png)

# %% [markdown]
# ## 목표

# %% [markdown]
# `-` 아래와 똑같은 그림을 `plt.plot()`을 쓰지 않고 만든다.

# %%
fig

# %% [markdown]
# ## Figure

# %%
fig2 = plt.Figure()

# %% [markdown]
# ## Axes

# %%
ax2 = fig2.add_axes([0.125, 0.11, 0.775, 0.77])

# %%
fig2

# %%
ax2.set_xlim([-0.15, 3.15])
ax2.set_ylim([0.9, 3.1])
# Out:
# (0.9, 3.1)

# %%
fig

# %%
line2 = matplotlib.lines.Line2D(
    xdata=[0,1,2,3], 
    ydata=[1,2,3,2], 
    linestyle='--', 
    marker='o'
)

# %%
ax2.add_line(line2)

# %%
fig

# %%
fig2

# %% [markdown]
# `-` Line2d 오브젝트를 쓰지 않는 방법

# %%
fig3 = plt.Figure()
ax3 = fig3.add_axes([0.125, 0.11, 0.775, 0.77])
ax3.plot([1,2,3,2],'--o')
fig3

# %% [markdown]
# `-` add_axes()를 쓰지 않는 방법

# %%
fig4 = plt.Figure()
ax4 = fig4.subplots()
ax4.plot([1,2,3,2],'--o')
fig4

# %% [markdown]
# `-` 더 생략하는 방법

# %%
fig5, ax5 = plt.subplots(1)
ax5.plot([1,2,3,2],'--o')

# %% [markdown]
# ## 정리

# %% [markdown]
# `-` 결국 아래는 모두 같은 코드이다.

# %%
## 코드1 
plt.plot([1,2,3,2],'--o')

# %%
## 코드2
fig,ax = plt.subplots()
ax.plot([1,2,3,2],'--o')

# %%
## 코드3
fig = plt.Figure()
ax = fig.subplots()
ax.plot([1,2,3,2],'--o')
fig

# %%
## 코드4
fig = plt.Figure()
ax = fig.add_axes([0.125, 0.11, 0.775, 0.77])
ax.plot([1,2,3,2],'--o')
fig

# %%
## 코드5
fig = plt.Figure()
ax = fig.add_axes([0.125, 0.11, 0.775, 0.77])
ax.set_xlim([-0.15, 3.15])
ax.set_ylim([0.9, 3.1])
line = matplotlib.lines.Line2D(
    xdata=[0,1,2,3], 
    ydata=[1,2,3,2], 
    linestyle='--', 
    marker='o'
)
ax.add_line(line)
fig

# %% [markdown]
# # 미니맵

# %% [markdown]
# `-` 틀잡기

# %%
fig = plt.Figure()
ax1 = fig.add_axes([0,0,2,2])
ax3 = fig.add_axes([1.4,0.2,0.5,0.5])
fig

# %%
ax1.plot([1,5,3,4],'--o')
ax3.plot([1,2,3,1],'--or')
fig

# %% [markdown]
# # HW

# %% [markdown]
# **제출: `이름(학번).ipynb`, `이름(학번).html` 형태로 정리하여 2개의 파일을 제출할 것 (작성방법 모르면 아래영상참고할것)**
# - 즉 주피터노트북파일과 html파일을 모두 제출할 것

# %% [markdown]
# <https://youtube.com/playlist?list=PLQqh36zP38-x3HQLeyrS7GLh70Dv_54Yg>

# %% [markdown]
# - 영상1: 코랩으로 실습하는 경우
# - 영상2: local 아나콘다로 실습하는 경우

# %% [markdown]
# `1`. 아래와 같은 그림을 그려라.

# %%
x,y = [1,2,3,4], [1,2,1,1]

# %%
#

# %% [markdown]
# `2`. 아래와 같은 그림을 그려라.

# %%
x = np.arange(-5,5,0.1)
y1 = np.sin(x)
y2 = np.sin(2*x) + 2
y3 = np.sin(4*x) + 4 
y4 = np.sin(8*x) + 6

# %%
#
