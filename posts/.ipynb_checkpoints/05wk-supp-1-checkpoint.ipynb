# %% [raw]
# ---
# title: "supp-1: FIFA23 자료의 시각화 -- draft"
# author: "최규빈"
# date: "10/06/2023"
# categories:
#   - pandas
# ---

# %% [markdown]
# <a href="https://colab.research.google.com/github/guebin/DV2023/blob/main/posts/05wk-supp-1.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" style="text-align: left"></a>

# %% [markdown]
# # 1. Imports

# %%
import pandas as pd
from plotnine import *

# %% [markdown]
# # 2. FIFA23 시각화 -- 문제

# %% [markdown]
# `# DV2022-중간고사-4-(2)의 변형`:
#
# 아래는 FIFA22의 자료를 불러오는 코드이다.

# %%
df = pd.read_csv('https://raw.githubusercontent.com/guebin/DV2021/master/_notebooks/2021-10-25-FIFA22_official_data.csv')
df.head()
# Out:
#        ID             Name  Age  \
# 0  212198  Bruno Fernandes   26
# 1  209658      L. Goretzka   26
# 2  176580        L. Suárez   34
# 3  192985     K. De Bruyne   30
# 4  224334         M. Acuña   29
#
#                                               Photo Nationality  \
# 0  https://cdn.sofifa.com/players/212/198/22_60.png    Portugal
# 1  https://cdn.sofifa.com/players/209/658/22_60.png     Germany
# 2  https://cdn.sofifa.com/players/176/580/22_60.png     Uruguay
# 3  https://cdn.sofifa.com/players/192/985/22_60.png     Belgium
# 4  https://cdn.sofifa.com/players/224/334/22_60.png   Argentina
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.com/flags/pt.png       88         89
# 1  https://cdn.sofifa.com/flags/de.png       87         88
# 2  https://cdn.sofifa.com/flags/uy.png       88         88
# 3  https://cdn.sofifa.com/flags/be.png       91         91
# 4  https://cdn.sofifa.com/flags/ar.png       84         84
#
# ...

# %% [markdown]
# 포지션별로 선수들의 능력치(`ShotPower`,`SlidingTackle`)와 급여(`Wage`)를 시각화하고 싶다. 아래의 세부지침에 맞추어 포지션별 `ShotPower`와 `SlidingTackle`의 산점도를 그려라. – (30점)

# %% [markdown]
# ***세부지침***
#
# **A**. Column의 이름에서 공백을 제거하라.
#
# **B**. 결측치가 50%이상인 컬럼을 찾고 이를 제거하라. 그 뒤에 `.dropna()`를 사용하여 결측치가 포함된 행을 제거하라.
#
# **C**. `position_dict`를 이용하여 `df.Position`을 적절하게 변환하라. 변환된 값을 `df.Position`에 저장하라.

# %%
position_dict = {
    'GOALKEEPER':{'GK'},
    'DEFENDER':{'CB','RCB','LCB','RB','LB','RWB','LWB'},
    'MIDFIELDER':{'CM','RCM','LCM','CDM','RDM','LDM','CAM','RAM','LAM','RM','LM'},
    'FORWARD':{'ST','CF','RF','LF','RW','LW','RS','LS'},
    'SUB':{'SUB'},
    'RES':{'RES'}
}
position_dict
# Out:
# {'GOALKEEPER': {'GK'},
#  'DEFENDER': {'CB', 'LB', 'LCB', 'LWB', 'RB', 'RCB', 'RWB'},
#  'MIDFIELDER': {'CAM',
#   'CDM',
#   'CM',
#   'LAM',
#   'LCM',
#   'LDM',
#   'LM',
#   'RAM',
#   'RCM',
#   'RDM',
#   'RM'},
#  'FORWARD': {'CF', 'LF', 'LS', 'LW', 'RF', 'RS', 'RW', 'ST'},
#  'SUB': {'SUB'},
#  'RES': {'RES'}}

# %% [markdown]
# **D**. `df.Wage`를 적절하게 변환하라.

# %% [markdown]
# **E**. `Position==“DEFENDER”` or `Position==“FORWARD”`에 해당하는 관측치를 고른 뒤 x축에 `ShotPower`, y축에 `SlidingTackle`을 시각화하라. 이때 `Position`은 color로 구분하고 `Wage`는 size와 alpha로 구분하라.

# %% [markdown]
# --- 시각화예시 ---

# %%
#
# Out:
# <Figure Size: (640 x 480)>

# %% [markdown]
# # 3. FIFA23 시각화 -- 풀이1

# %% [markdown]
# ## A. 열의 이름에서 공백제거

# %% [markdown]
# ## B. 결측치제거

# %% [markdown]
# ## C. Position 칼럼의 변환

# %% [markdown]
# ## D. Wage 칼럼의 변환

# %% [markdown]
# ## E. 시각화

# %% [markdown]
# # 4. FIFA23 시각화 -- 말리는 풀이

# %% [markdown]
# # 5. FIFA23 시각화 -- 풀이2

# %% [markdown]
# ## A. 열의 이름에서 공백제거

# %%
df.set_axis(df.columns.str.replace(' ',''),axis=1)
# Out:
#            ID             Name  Age  \
# 0      212198  Bruno Fernandes   26
# 1      209658      L. Goretzka   26
# 2      176580        L. Suárez   34
# 3      192985     K. De Bruyne   30
# 4      224334         M. Acuña   29
# ...       ...              ...  ...
# 16705  240558    18 L. Clayton   17
# 16706  262846         �. Dobre   20
# 16707  241317   21 Xue Qinghao   19
# 16708  259646        A. Shaikh   18
# 16709  178453    07 A. Censori   17
#
#                                                   Photo Nationality  \
# 0      https://cdn.sofifa.com/players/212/198/22_60.png    Portugal
# 1      https://cdn.sofifa.com/players/209/658/22_60.png     Germany
# 2      https://cdn.sofifa.com/players/176/580/22_60.png     Uruguay
# 3      https://cdn.sofifa.com/players/192/985/22_60.png     Belgium
# 4      https://cdn.sofifa.com/players/224/334/22_60.png   Argentina
# ...                                                 ...         ...
# ...

# %% [markdown]
# ## B. 결측치제거

# %%
df.set_axis(df.columns.str.replace(' ',''),axis=1)\
.drop(['Marking','LoanedFrom'],axis=1).dropna()
# Out:
#            ID             Name  Age  \
# 0      212198  Bruno Fernandes   26
# 1      209658      L. Goretzka   26
# 2      176580        L. Suárez   34
# 3      192985     K. De Bruyne   30
# 4      224334         M. Acuña   29
# ...       ...              ...  ...
# 16703  259718      F. Gebhardt   19
# 16704  251433          B. Voll   20
# 16706  262846         �. Dobre   20
# 16707  241317   21 Xue Qinghao   19
# 16708  259646        A. Shaikh   18
#
#                                                   Photo Nationality  \
# 0      https://cdn.sofifa.com/players/212/198/22_60.png    Portugal
# 1      https://cdn.sofifa.com/players/209/658/22_60.png     Germany
# 2      https://cdn.sofifa.com/players/176/580/22_60.png     Uruguay
# 3      https://cdn.sofifa.com/players/192/985/22_60.png     Belgium
# 4      https://cdn.sofifa.com/players/224/334/22_60.png   Argentina
# ...                                                 ...         ...
# ...

# %% [markdown]
# ## C. Position 칼럼의 변환

# %%
_df = df.set_axis(df.columns.str.replace(' ',''),axis=1)\
.drop(['Marking','LoanedFrom'],axis=1).dropna()

# %%
position_dict
# Out:
# {'GOALKEEPER': {'GK'},
#  'DEFENDER': {'CB', 'LB', 'LCB', 'LWB', 'RB', 'RCB', 'RWB'},
#  'MIDFIELDER': {'CAM',
#   'CDM',
#   'CM',
#   'LAM',
#   'LCM',
#   'LDM',
#   'LM',
#   'RAM',
#   'RCM',
#   'RDM',
#   'RM'},
#  'FORWARD': {'CF', 'LF', 'LS', 'LW', 'RF', 'RS', 'RW', 'ST'},
#  'SUB': {'SUB'},
#  'RES': {'RES'}}

# %%
_df.Position.str.split('>').str[-1].apply(lambda x: [k for k,v in position_dict.items() if x in v][0])
# Out:
# 0        MIDFIELDER
# 1        MIDFIELDER
# 2           FORWARD
# 3        MIDFIELDER
# 4          DEFENDER
#             ...
# 16703           RES
# 16704           RES
# 16706           RES
# 16707           RES
# 16708           SUB
# Name: Position, Length: 14398, dtype: object

# %% [markdown]
# ## D. Wage 칼럼의 변환

# %% [markdown]
# ## E. 시각화

# %%
fig = ggplot(tidydata.query('Position=="DEFENDER" or Position=="FORWARD"'))
point = geom_point(aes(x='ShotPower',y='SlidingTackle',color='Position',size='Wage',alpha='Wage'),position='jitter')
fig+point
# Out:
# <Figure Size: (640 x 480)>
