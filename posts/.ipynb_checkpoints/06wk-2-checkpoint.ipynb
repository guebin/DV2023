# %% [raw]
# ---
# title: "06wk-2: 심슨의 역설"
# author: "최규빈"
# date: "10/11/2023"
# draft: false
# categories:
#   - plotnine
# ---

# %% [markdown]
# <a href="https://colab.research.google.com/github/guebin/DV2023/blob/main/posts/06wk-2.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" style="text-align: left"></a>

# %% [markdown]
# # 1. 강의영상

# %% [markdown]
# # 2. Imports

# %%
import pandas as pd
import numpy as np
from plotnine import *

# %% [markdown]
# # 3. 비교를 위한 시각화

# %% [markdown]
# ## A. `geom_col()`

# %% [markdown]
# `-` 예시1: 기본적인 막대그래프

# %%
df = pd.DataFrame({'x':[0,1],'y':[40,60]})
df
# Out:
#    x   y
# 0  0  40
# 1  1  60

# %%
fig = ggplot(df)
bar = geom_col(aes(x='x',y='y'))
fig + bar
# Out:
# <Figure Size: (640 x 480)>

# %% [markdown]
# `-` 예시2: $x$축이 범주인 경우

# %%
df = pd.DataFrame({'sex':['male','female'],'score':[40,60]})
df
# Out:
#       sex  score
# 0    male     40
# 1  female     60

# %%
fig = ggplot(df)
bar = geom_col(aes(x='sex',y='score'))
fig+bar
# Out:
# <Figure Size: (640 x 480)>

# %% [markdown]
# `-` 예시3: 예시2에서 색깔로 구분하고 싶은 경우

# %%
df = pd.DataFrame({'sex':['male','female'],'score':[40,60]})
df
# Out:
#       sex  score
# 0    male     40
# 1  female     60

# %%
fig = ggplot(df)
bar = geom_col(aes(x='sex',y='score',fill='sex'))
fig+bar
# Out:
# <Figure Size: (640 x 480)>

# %% [markdown]
# `-` 예시4: 예시3에서 `scale_fill_manual()`을 이용하여 색상변경 하기

# %%
df = pd.DataFrame({'sex':['male','female'],'score':[40,60]})
df
# Out:
#       sex  score
# 0    male     40
# 1  female     60

# %%
fig = ggplot(df)
bar = geom_col(aes(x='sex',y='score',fill='sex'))
fig+bar+scale_fill_manual(['red','blue']) # 헥사코드구해서 넣어도..
# Out:
# <Figure Size: (640 x 480)>

# %% [markdown]
# ## B. `facet_wrap()`

# %% [markdown]
# `-` 예시1: `facet_wrap()`을 이용한 면분할 -- 반별로 면분할

# %%
df = pd.DataFrame({'sex':['male','female','male','female'],'score':[40,60,50,20],'class':['A','A','B','B']})
df
# Out:
#       sex  score class
# 0    male     40     A
# 1  female     60     A
# 2    male     50     B
# 3  female     20     B

# %%
ggplot(df) + geom_col(aes(x='sex',y='score',fill='sex')) + facet_wrap('class')
# Out:
# <Figure Size: (640 x 480)>

# %% [markdown]
# `-` 예시2: `facet_wrap()`을 이용한 면분할 -- 성별로 면분할

# %%
df = pd.DataFrame({'sex':['male','female','male','female'],'score':[40,60,50,20],'class':['A','A','B','B']})
df
# Out:
#       sex  score class
# 0    male     40     A
# 1  female     60     A
# 2    male     50     B
# 3  female     20     B

# %%
ggplot(df) + geom_col(aes(x='class',y='score',fill='sex')) + facet_wrap('sex')
# Out:
# <Figure Size: (640 x 480)>

# %% [markdown]
# # 4. 심슨의 역설

# %% [markdown]
# `-` 버클리대학교의 입학데이터
#
# - <https://github.com/guebin/DV2023/blob/main/posts/ds.pdf>

# %% [markdown]
# `-` 주장: 버클리대학에 gender bias가 존재한다.
#
# - 1973년 가을학기의 입학통계에 따르면 지원하는 남성이 여성보다 훨씬 많이 합격했고, 그 차이가 너무 커서 우연의 일치라 보기 어렵다.

# %%
df=pd.read_csv("https://raw.githubusercontent.com/guebin/DV2022/master/posts/Simpson.csv",index_col=0,header=[0,1])\
.stack().stack().reset_index()\
.rename({'level_0':'department','level_1':'result','level_2':'gender',0:'count'},axis=1)
df
# Out:
#    department result  gender  count
# 0           A   fail    male    314
# 1           A   fail  female     19
# 2           A   pass    male    511
# 3           A   pass  female     89
# 4           B   fail    male    208
# 5           B   fail  female      7
# 6           B   pass    male    352
# 7           B   pass  female     18
# 8           C   fail    male    204
# 9           C   fail  female    391
# 10          C   pass    male    121
# 11          C   pass  female    202
# 12          D   fail    male    279
# 13          D   fail  female    244
# 14          D   pass    male    138
# 15          D   pass  female    131
# 16          E   fail    male    137
# 17          E   fail  female    299
# 18          E   pass    male     54
# 19          E   pass  female     94
# 20          F   fail    male    149
# 21          F   fail  female    103
# 22          F   pass    male    224
# 23          F   pass  female    238

# %% [markdown]
# ## A. 시각화1: 전체합격률 시각화 -- pandas 초보

# %% [markdown]
# ## B. 시각화1: 전체합격률 시각화 -- pandas 고수

# %%
df.pivot_table(index='gender',columns='result',values='count',aggfunc=sum)
# Out:
# /tmp/ipykernel_1854638/1986990674.py:1: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
# result  fail  pass
# gender
# female  1063   772
# male    1291  1400

# %%
df.pivot_table(index='gender',columns='result',values='count',aggfunc=sum)\
.assign(rate = lambda _df: _df['pass']/(_df['fail'] + _df['pass']))\
.reset_index()
# Out:
# /tmp/ipykernel_1854638/3361715289.py:1: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
# result  gender  fail  pass      rate
# 0       female  1063   772  0.579292
# 1         male  1291  1400  0.479747

# %%
tidydata = df.pivot_table(index='gender',columns='result',values='count',aggfunc=sum).assign(rate = lambda _df: _df['pass']/(_df['fail'] + _df['pass'])).reset_index()
fig = ggplot(tidydata) 
bar = geom_col(aes(x='gender',fill='gender',y='rate'))
fig+bar
# Out:
# /tmp/ipykernel_1854638/3745418927.py:1: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
# <Figure Size: (640 x 480)>

# %% [markdown]
# ## C. 시각화1: 학과별합격률 시각화 -- pandas 고수

# %%
df.pivot_table(index=['department'],columns=['result','gender'],values='count',aggfunc=sum).stack()\
.assign(rate = lambda _df: _df['pass']/(_df['fail'] + _df['pass']))\
.drop(['fail','pass'],axis=1)\
.reset_index()
# Out:
# /tmp/ipykernel_1854638/319699419.py:1: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
# result department  gender      rate
# 0               A  female  0.824074
# 1               A    male  0.619394
# 2               B  female  0.720000
# 3               B    male  0.628571
# 4               C  female  0.340641
# 5               C    male  0.372308
# 6               D  female  0.349333
# 7               D    male  0.330935
# 8               E  female  0.239186
# 9               E    male  0.282723
# 10              F  female  0.697947
# 11              F    male  0.600536

# %%
tidydata = df.pivot_table(index=['department'],columns=['result','gender'],values='count',aggfunc=sum).stack()\
.assign(rate = lambda _df: _df['pass']/(_df['fail'] + _df['pass']))\
.drop(['fail','pass'],axis=1)\
.reset_index()

fig = ggplot(tidydata)
bar = geom_col(aes(x='gender',y='rate',fill='gender'))
fig+bar+facet_wrap('department')
# Out:
# /tmp/ipykernel_1854638/804508431.py:1: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
# <Figure Size: (640 x 480)>

# %% [markdown]
# ## D. 해석

# %% [markdown]
# `-` 시각화1: 남자의 합격률이 더 높다. $\to$ 성차별이 있어보인다(?)

# %% [markdown]
# `-` 시각화2: 학과별로 살펴보니 오히려 A,B,F,D의 경우 여성의 합격률이 높다.

# %% [markdown]
# `-` 교재에서 설명한 이유: 여성이 합격률이 낮은 학과에만 많이 지원하였기 때문

# %%
df.pivot_table(index='department',columns='gender',values='count',aggfunc=sum)\
.stack().reset_index().rename({0:'count'},axis=1)
# Out:
# /tmp/ipykernel_1854638/3994962511.py:1: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#    department  gender  count
# 0           A  female    108
# 1           A    male    825
# 2           B  female     25
# 3           B    male    560
# 4           C  female    593
# 5           C    male    325
# 6           D  female    375
# 7           D    male    417
# 8           E  female    393
# 9           E    male    191
# 10          F  female    341
# 11          F    male    373

# %%
tidydata = df.pivot_table(index='department',columns='gender',values='count',aggfunc=sum)\
.stack().reset_index().rename({0:'count'},axis=1)

fig = ggplot(tidydata)
bar = geom_col(aes(x='department',y='count',fill='gender'),position='dodge')
fig+bar
# Out:
# /tmp/ipykernel_1854638/2720206934.py:1: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
# <Figure Size: (640 x 480)>

# %% [markdown]
# - 살펴보니 합격률이 높은 A,B학과의 경우 상대적으로 남성이 많이 지원하였음. 합격률이 낮은 C,D학과는 상대적으로 여성이 많이 지원함. D,F의 지원수는 비슷
