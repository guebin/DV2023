# %% [raw]
# ---
# title: "03wk-1: plotnine(ggplot2), 아이스크림을 많이 먹으면 걸리는 병 (draft)"
# author: "최규빈"
# date: "09/18/2023"
# draft: true
# categories:
#   - plotnine
# ---

# %% [markdown]
# <a href="https://colab.research.google.com/github/guebin/DV2023/blob/main/posts/03wk-1.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" style="text-align: left"></a>

# %% [markdown]
# # 1. 강의영상

# %%
# {{<video https://youtu.be/playlist?list=PLQqh36zP38-yHabB3SMhPt0toFJTIKgPy&si=bgcDaORN0s4Hkrhv >}}

# %% [markdown]
# # 2. Imports

# %%
# !pip install plotnine -- 설치해야해요~

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
from plotnine import *

# %%
import plotnine

# %%
plotnine.options.dpi= 150
plotnine.options.figure_size = (5,5)

# %% [markdown]
# # 3. `mpg` data

# %% [markdown]
# ## A. read data

# %% [markdown]
# `-` ref: <https://r4ds.had.co.nz/index.html>

# %%
df = pd.read_csv('https://raw.githubusercontent.com/guebin/DV2022/master/posts/mpg.csv')

# %% [markdown]
# ## B. descriptions

# %% [markdown]
# `-` 컬럼들의 이름을 출력.

# %% [markdown]
# `-` ChatGPT에 문의

# %% [markdown]
# ![](attachment:d0bca24b-da24-41af-8954-a415135b817c.png)

# %% [markdown]
# # 4. `mpg`의 시각화: 2차원

# %% [markdown]
# ## A. `x=displ`, `y=hwy`

# %% [markdown]
# `-` 예시1: 정직하게 매뉴얼대로..

# %% [markdown]
# `-` 예시2: `data=`와 `mapping=`은 생략가능하다.

# %% [markdown]
# ## B. `rpy2`

# %% [markdown]
# `-` 예시: R에서도 거의 똑같은 문법으로 그릴수 있음 (1타2피..)

# %%
import rpy2
# %load_ext rpy2.ipython
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %% [markdown]
# # 5. `mpg`의 시각화: 3차원

# %% [markdown]
# ## A. `x=displ`, `y=hwy`, `shape=class`

# %% [markdown]
# `-` 예시1

# %% [markdown]
# ## B. `x=displ`, `y=hwy`, `color=class`

# %% [markdown]
# ## C. `x=displ`, `y=hwy`, `color=class`, `shape=class`

# %% [markdown]
# `-` 예시1

# %% [markdown]
# `-` 예시2: 전체적으로 size를 크게..

# %% [markdown]
# `-` 예시3: 겹치는 부분이 있으니 좀 더 투명하게..

# %% [markdown]
# # 6. `mpg`의 시각화: 4차원, 5차원

# %% [markdown]
# ## A. `x=displ`, `y=hwy`, `color=drv`, `shape=class`

# %% [markdown]
# ## B. `x=displ`, `y=hwy`, `color=drv`, `shape=class`, `size=cyl`

# %% [markdown]
# # 7. 객체지향적 시각화

# %% [markdown]
# `-` `ggplot`은 정체가 뭐지?

# %% [markdown]
# `-` `geom_point`은 정체가 뭐지?

# %% [markdown]
# ## A. `fig`

# %% [markdown]
# ## B. `geom_point()`

# %% [markdown]
# ## C. `geom_smooth()`

# %% [markdown]
# ## D. `geom_point()` + `geom_smooth()`

# %% [markdown]
# ## E. `geom_point()` -- better

# %% [markdown]
# ## F. `geom_smooth()` -- better

# %% [markdown]
# ## G. 다양한 조합

# %% [markdown]
# `-` 예시1: fig, point, smooth

# %% [markdown]
# `-` 예시2: fig, point_better, smooth_better

# %% [markdown]
# `-` 예시3: fig, point_better, smooth_better, smooth

# %% [markdown]
# # 8. 아이스크림을 많이 먹으면 걸리는 병

# %% [markdown]
# ## A. 책 읽어보세요

# %% [markdown]
# `-` ref: <https://product.kyobobook.co.kr/detail/S000000597846>
#
# - 구매할만한 책입니다.
# - 수업에 필요한 내용은 [여기](https://github.com/guebin/DV2023/blob/main/posts/ds.pdf)에..

# %% [markdown]
# `-` 내용요약
# - 여름  $\to$ 수영장 $\to$ 소아마비
# - 여름  $\to$ 아이스크림
# - 아이스크림과 소아마비는 상관관계가 높다: 아이스크림 성분중에서 소아마비를 유발하는 유해물질이 있을 것이다 (?)

# %% [markdown]
# ## B. 기상자료 다운로드

# %% [markdown]
# `-` 기상자료 다운로드

# %%
temp=pd.read_csv('https://raw.githubusercontent.com/guebin/DV2022/master/posts/temp.csv').iloc[:,3].to_numpy()
#temp

# %% [markdown]
# ## C. 숨은진짜상황1: 온도 $\to$ 아이스크림 판매량

# %% [markdown]
# `-` 아래와 같은 관계를 가정하자.
#
#
# $$\text{아이스크림 판매량} = 20 + 2 \times \text{온도} + \text{오차}$$

# %% [markdown]
# ## D. 숨은진짜상황2: 온도 $\to$ 소아마비 반응수치

# %% [markdown]
# `-` 아래와 같은 관계를 가정하자.

# %% [markdown]
# $$\text{소아마비 반응수치} = 30 + 0.5 \times \text{온도} + \text{오차}$$

# %% [markdown]
# ## E. 우리가 관측한 상황 (온도는 은닉되어 있음)

# %% [markdown]
# ## F. 여름만 뽑아서 플랏한다면?

# %% [markdown]
# ## G. `ggplot`으로 온도구간을 세분화 하여 시각화하자.

# %% [markdown]
# `-` 데이터를 데이터프레임으로

# %% [markdown]
# `-` 구간별로 나눈변수를 추가

# %% [markdown]
# `-` 시각화

# %% [markdown]
# ## H. 진짜 아이스크림을 먹고 배탈이 났다면?

# %% [markdown]
# `-` 온도는 아이스크림 판매에 여전히 영향을 주지만
#
# $$\text{아이스크림 판매량} = 20 + 2 \times \text{온도} + \text{오차}$$

# %%
np.random.seed(2)
icecream = 30 + 0.5 * temp + np.random.randn(len(temp))*1

# %% [markdown]
# `-` 수영장이 원인이 아니라 진짜 아이스크림을 먹고 소아마비에 걸린상황이라면?

# %% [markdown]
# $$\text{소아마비 반응수치} = 30 + 0.0 \times \text{온도} + 0.15 \times \text{아이스크림 판매량} + \text{오차}$$

# %%
np.random.seed(2) 
disease= 30+ 0*temp + 0.15*icecream + np.random.normal(size=len(temp),scale=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[122], line 2
#       1 np.random.seed(2)
# ----> 2 disease= 30+ 0*temp + 0.15*icecream + np.random.normal(size=len(temp),scale=2)
#
# NameError: name 'icecream' is not defined

# %% [markdown]
# `-` 그림을 한번 그려보자.

# %%
df2 = pd.DataFrame({'temp':temp,'ice':icecream,'dis':disease})
df2.assign(temp_cut=pd.cut(df2.temp,bins=7))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[123], line 1
# ----> 1 df2 = pd.DataFrame({'temp':temp,'ice':icecream,'dis':disease})
#       2 df2.assign(temp_cut=pd.cut(df2.temp,bins=7))
#
# NameError: name 'icecream' is not defined

# %%
fig = ggplot(df2.assign(temp_cut = pd.cut(df2.temp,bins=7))) 
point = geom_point(aes(x='ice',y='dis',color='temp_cut'),alpha=0.2)
smooth = geom_smooth(aes(x='ice',y='dis',color='temp_cut'),linetype='dashed')
fig + point + smooth
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[124], line 1
# ----> 1 fig = ggplot(df2.assign(temp_cut = pd.cut(df2.temp,bins=7)))
#       2 point = geom_point(aes(x='ice',y='dis',color='temp_cut'),alpha=0.2)
#       3 smooth = geom_smooth(aes(x='ice',y='dis',color='temp_cut'),linetype='dashed')
#
# NameError: name 'df2' is not defined

# %% [markdown]
# ## I. 해석

# %% [markdown]
# `-` 해피앤딩: 아이스크림 먹어도 소아마비 안걸려!
#
# - 아이스크림을 먹으면 소아마비를 유발한다는 이상한 결론이 나올뻔 했음.
# - 하지만 우리는 온도라는 흑막^[우리는 이것을 "은닉변수"라고 부르기로 했어요]을 잘 찾았고 결과적으로 “온도->아이스크림판매량,소아마비” 이라는 합리적인 진리를 얻을 수 있었다.

# %% [markdown]
# `-` 걱정: 또 다른 흑막?
#
# - 고려할 흑막이 온도뿐이라는 보장이 어디있지?
# - 사실 흑막2, 흑막3이 있어서 그런 흑막들을 고려하다보니까 아이스크림과 소아마비사이의 상관관계가 다시 보인다면?

# %% [markdown]
# `-` 이론:
#
# - 이론적으로는 “세상의 모든 은닉변수를 통제하였을 경우에도 corr(X,Y)의 값이 1에 가깝다면 그때는 인과성이 있음” 이라고 주장할 수 있다.^[물론 이 경우에도 무엇이 원인인지는 통계적으로 따지는 것은 불가]
# - **즉 모든 흑막을 제거한다면 “상관성=인과성”이다.**

# %% [markdown]
# `-` 회의론:
#
# - 세상의 모든 흑막을 제거하는건 사실상 불가능하지 않나?

# %% [markdown]
# `-` 두 가지 연구흐름
#
# - 실험계획법: 실험계획을 잘하면 흑막을 제거한 효과가 있음.^[무작위로 사람뽑아서 담배를 피우게 한다든가]
# - 인과추론: 실험계획이 사실상 불가능한 경우가 있음 $\to$ 모인 데이터에서 최대한 흑막2,3,4,.. 등이 비슷한 그룹끼리 “매칭”을 시킨다!
